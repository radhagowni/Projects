# %%
boat_side = 'Right'
missionaries_on_right = 3
cannibals_on_right = 3
missionaries_on_left = 0
cannibals_on_left = 0

print('M=','\U0001f479'*missionaries_on_left, 'C=','\U0001f482'*cannibals_on_left, "|", '\U0001f30a'*4, '\U0001f6A2', "|", 'M=','\U0001f479'*missionaries_on_right,'C=','\U0001f482'*cannibals_on_right)

while True:

    missionaries = int(input('No of missionaries or enter 10 to quit : '))
    if missionaries == 10:
        print('You Quit. Game Over!')
        break
    cannibals = int(input('No of cannibals : '))

    if (missionaries + cannibals) != 1 and (missionaries + cannibals) != 2:
        print('Invalid Move')
        continue


    if boat_side == 'Right':
        if missionaries_on_right < missionaries or cannibals_on_right < cannibals :
            print('Invalid Move')

        missionaries_on_right = missionaries_on_right - missionaries
        cannibals_on_right = cannibals_on_right - cannibals

        missionaries_on_left += missionaries
        cannibals_on_left += cannibals

        print('M=' ,'\U0001f479'*missionaries_on_left, 'C=','\U0001f482'*cannibals_on_left,"|",'\U0001f6A2','\U0001f30a'*4,"|", 'M=','\U0001f479'*missionaries_on_right,'C=','\U0001f482'*cannibals_on_right)

        boat_side = 'Left'

    else:
        if missionaries_on_left < missionaries or cannibals_on_left < cannibals:
            print('Invalid Move')


        missionaries_on_left = missionaries_on_left - missionaries
        cannibals_on_left = cannibals_on_left - cannibals

        missionaries_on_right += missionaries
        cannibals_on_right += cannibals

        print('M=','\U0001f479'*missionaries_on_left, 'C=','\U0001f482'*cannibals_on_left, "|",'\U0001f30a'*4,'\U0001f6A2',"|", 'M=','\U0001f479'*missionaries_on_right,'C=','\U0001f482'*cannibals_on_right)
        boat_side = 'Right'

    if (missionaries_on_right < cannibals_on_right and missionaries_on_right > 0) and (missionaries_on_left < cannibals_on_left and missionaries_on_left > 0):
        print('You Loose')
        break

    if(missionaries_on_left == 3 and cannibals_on_left == 3):
        print('You win')
        break
# Out:
# M=  C=  | 🌊🌊🌊🌊 🚢 | M= 👹👹👹 C= 💂💂💂
# No of missionaries or enter 10 to quit : 1
# No of cannibals : 1
# M= 👹 C= 💂 | 🚢 🌊🌊🌊🌊 | M= 👹👹 C= 💂💂
# No of missionaries or enter 10 to quit : 0
# No of cannibals : 1
# M= 👹 C=  | 🌊🌊🌊🌊 🚢 | M= 👹👹 C= 💂💂💂
# No of missionaries or enter 10 to quit : 2
# No of cannibals : 0
# M= 👹👹👹 C=  | 🚢 🌊🌊🌊🌊 | M=  C= 💂💂💂
# No of missionaries or enter 10 to quit : 1
# No of cannibals : 0
# M= 👹👹 C=  | 🌊🌊🌊🌊 🚢 | M= 👹 C= 💂💂💂
# No of missionaries or enter 10 to quit : 0
# No of cannibals : 2
# M= 👹👹 C= 💂💂 | 🚢 🌊🌊🌊🌊 | M= 👹 C= 💂
# No of missionaries or enter 10 to quit : 1
# No of cannibals : 1
# M= 👹 C= 💂 | 🌊🌊🌊🌊 🚢 | M= 👹👹 C= 💂💂
# No of missionaries or enter 10 to quit : 0
# No of cannibals : 2
# M= 👹 C= 💂💂💂 | 🚢 🌊🌊🌊🌊 | M= 👹👹 C=
# No of missionaries or enter 10 to quit : 1
# No of cannibals : 0
# M=  C= 💂💂💂 | 🌊🌊🌊🌊 🚢 | M= 👹👹👹 C=
# No of missionaries or enter 10 to quit : 2
# No of cannibals : 0
# M= 👹👹 C= 💂💂💂 | 🚢 🌊🌊🌊🌊 | M= 👹 C=
# No of missionaries or enter 10 to quit : 1
# ...

# %%
boat_side = 'Right'
missionaries_on_right = 3
cannibals_on_right = 3
missionaries_on_left = 0
cannibals_on_left = 0

print('M=','\U0001f479'*missionaries_on_left, 'C=','\U0001f482'*cannibals_on_left, "|", '\U0001f30a'*4, '\U0001f6A2', "|", 'M=','\U0001f479'*missionaries_on_right,'C=','\U0001f482'*cannibals_on_right)

while True:

    missionaries = int(input('No of missionaries or enter 10 to quit : '))
    if missionaries == 10:
        print('You Quit. Game Over!')
        break
    cannibals = int(input('No of cannibals : '))

    if (missionaries + cannibals) != 1 and (missionaries + cannibals) != 2:
        print('Invalid Move')
        continue


    if boat_side == 'Right':
        if missionaries_on_right < missionaries or cannibals_on_right < cannibals :
            print('Invalid Move')

        missionaries_on_right = missionaries_on_right - missionaries
        cannibals_on_right = cannibals_on_right - cannibals

        missionaries_on_left += missionaries
        cannibals_on_left += cannibals

        print('M=' ,'\U0001f479'*missionaries_on_left, 'C=','\U0001f482'*cannibals_on_left,"|",'\U0001f6A2','\U0001f30a'*4,"|", 'M=','\U0001f479'*missionaries_on_right,'C=','\U0001f482'*cannibals_on_right)

        boat_side = 'Left'

    else:
        if missionaries_on_left < missionaries or cannibals_on_left < cannibals:
            print('Invalid Move')


        missionaries_on_left = missionaries_on_left - missionaries
        cannibals_on_left = cannibals_on_left - cannibals

        missionaries_on_right += missionaries
        cannibals_on_right += cannibals

        print('M=','\U0001f479'*missionaries_on_left, 'C=','\U0001f482'*cannibals_on_left, "|",'\U0001f30a'*4,'\U0001f6A2',"|", 'M=','\U0001f479'*missionaries_on_right,'C=','\U0001f482'*cannibals_on_right)
        boat_side = 'Right'

    if (missionaries_on_right < cannibals_on_right and missionaries_on_right > 0) and (missionaries_on_left < cannibals_on_left and missionaries_on_left > 0):
        print('You Loose')
        break

    if(missionaries_on_left == 3 and cannibals_on_left == 3):
        print('You win')
        break
# Out:
# M=  C=  | 🌊🌊🌊🌊 🚢 | M= 👹👹👹 C= 💂💂💂
# No of missionaries or enter 10 to quit : 1
# No of cannibals : 1
# M= 👹 C= 💂 | 🚢 🌊🌊🌊🌊 | M= 👹👹 C= 💂💂
# No of missionaries or enter 10 to quit : 1
# No of cannibals : 0
# M=  C= 💂 | 🌊🌊🌊🌊 🚢 | M= 👹👹👹 C= 💂💂
# No of missionaries or enter 10 to quit : 2
# No of cannibals : 1
# Invalid Move
# No of missionaries or enter 10 to quit : 1
# No of cannibals : 1
# M= 👹 C= 💂💂 | 🚢 🌊🌊🌊🌊 | M= 👹👹 C= 💂
# No of missionaries or enter 10 to quit : 1
# No of cannibals : 2
# Invalid Move
# No of missionaries or enter 10 to quit : 9
# No of cannibals : 1
# Invalid Move
# No of missionaries or enter 10 to quit : 10
# You Quit. Game Over!
